# %% [markdown]
# # Filtering Down the Scheduled Task Data Overview
#
# **Description of Dataset**
# - Over 12,000 CSV files in directory
# - Over 5 million rows of Scheduled Task Data
# - 28 columns, per row
#
# **Objective:**
# - Filter down the massive _Scheduled Task Dataset_ to a more managable size
#
# **Sections:**
# 1. Functions Used
# 2. Pre-Specified File Paths
# 3. Combining CSV Files
# 4. Counting Unique Tasks
# 5. Filtering Out Pre-Specified Tasks
# 6. Output / Verification

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 1:__ _Functions Used_ ###
# __Note:__
# - These functions are used throughout the script
# - Can easily be repurposed for other projects
# - Stored in Python as a _Function_

# %%
## CREATES A LIST FROM A SINGLE FILE ##
def create_list_from_file(file_path):
    from csv import reader
    file = open(file_path)
    read_file = reader(file)
    list_of_file = list(read_file)[1:]
    return list_of_file

## USED TO FILTER THE DATASET FOR TASKS ##
def VanillaFilter(TaskName):
    for eachtask in VanillaTasks:
        if str(eachtask) in TaskName:
            return True
    return False

## CREATES A DATAFRAME FROM A DIRECTORY OF CSV FILES ##
def dataframe_from_directory(directory_path):
    import glob
    import pandas as pd
    files = glob.glob(directory_path)
    df = pd.concat([pd.read_csv(fp) for fp in files], ignore_index=True)
    return df

## COUNTS THE NUMBER OF INSTANCES FOR EACH UNIQUE SCHEDULED TASKS ##
def counting_unique_tasks(directory_path):
    def dataframe_from_directory(directory_path):
        import glob
        import pandas as pd
        files = glob.glob(directory_path)
        df = pd.concat([pd.read_csv(fp) for fp in files], ignore_index=True)
        return df   
    unfiltered_data = dataframe_from_directory(directory_path)
    data = unfiltered_data[unfiltered_data.TaskName != 'TaskName']    
    values = data['TaskName'].value_counts(dropna=False).keys().tolist()
    counts = data['TaskName'].value_counts(dropna=False).tolist()
    value_dict = dict(zip(values, counts))    
    task_num = 0
    print('Total Num. of Unique Tasks:', len(value_dict))
    for key in value_dict:
        task_num += 1
        print('Task', task_num, '---', 'Count:', value_dict[key], '---', 'TaskName:', key)

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 2:__ _Pre-Specified File Paths (INPUT)_ ###
# __Note:__
# - These are the _only_ two inputs needed, other than determining what tasks to filter for
# - This is the _only_ place where the user _must_ interact with the script
#
# __Instructions:__
# - Paste the filepaths directly between the apostrophes for 'directory_path' and 'file_path'
# - If the filepath is not working, try adding a lowercase letter 'r' in front of the first apostrophe
#         - Example: directory_path = r'C:\Users\guest\Desktop\TEST2\*.csv'
#         - Example: file_path = r'C:\Users\guest\Desktop\VanillaTasks.csv'
# - Make sure to include '*.csv' at the end of your filepath for directory (see above)
#     - This ensures that all files ending in .csv are selected
# - Stored in Python as a _String_

# %%
## DIRECTORY OF SCHEDULED TASK DATA ##
directory_path = '' 

## CSV OF TASKS DEEMED 'VANILLA' OR 'SAFE' ##
file_path = ''

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 3:__ _Combining CSV Files_ ###
# __Note:__
# - Combines all CSV files within the specified directory into one massive dataset
# - Prints the length of the combined dataset
#     - Used to check for mistakes at the end of the script
# - Stored in Python as a _List of Lists_

# %%
## COMBINES CSVs ##
import os
import glob
fulldataset = []
for fname in glob.glob(directory_path):
    fname_as_list = create_list_from_file(fname)
    fulldataset = fulldataset + fname_as_list
print(len(fulldataset))
# Out:
# 2221

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 4:__ _Counting Unique Tasks_ ###
# __Note:__
# - Prints the total number of unique Scheduled Tasks found within the entire, unfiltered dataset
# - Prints the number of times each Scheduled Task occurs
# - __Warning:__
#     - If used on the entire dataset of 12,000+ files, you may have hundreds, if not thousands, of unique scheduled task names
#     - During testing, using a sample of 2000+ entries returned around ~350 unique tasks
# - Stored in Python as a _Dictionary_

# %%
counting_unique_tasks(directory_path)
# Out:
# Total Num. of Unique Tasks: 342
# Task 1 --- Count: 25 --- TaskName: \Microsoft\Windows\CertificateServicesClient\KeyPreGenTask
# Task 2 --- Count: 24 --- TaskName: \Microsoft\Windows\InstallService\SmartRetry
# Task 3 --- Count: 23 --- TaskName: \Microsoft\Windows\Windows Error Reporting\QueueReporting
# Task 4 --- Count: 20 --- TaskName: \Microsoft\Windows\CertificateServicesClient\UserTask
# Task 5 --- Count: 20 --- TaskName: \Microsoft\Windows\WindowsUpdate\Scheduled Start
# Task 6 --- Count: 20 --- TaskName: \Microsoft\Windows\Flighting\FeatureConfig\ReconcileFeatures
# Task 7 --- Count: 20 --- TaskName: \Microsoft\Windows\MemoryDiagnostic\ProcessMemoryDiagnosticEvents
# Task 8 --- Count: 20 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Schedule Scan Static Task
# Task 9 --- Count: 19 --- TaskName: \Microsoft\Windows\TPM\Tpm-Maintenance
# Task 10 --- Count: 19 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Schedule Scan
# Task 11 --- Count: 16 --- TaskName: \Microsoft\Windows\USB\Usb-Notifications
# Task 12 --- Count: 15 --- TaskName: \Microsoft\Windows\Subscription\LicenseAcquisition
# Task 13 --- Count: 15 --- TaskName: \Microsoft\Windows\Subscription\EnableLicenseAcquisition
# Task 14 --- Count: 15 --- TaskName: \Microsoft\Windows\CertificateServicesClient\SystemTask
# Task 15 --- Count: 14 --- TaskName: \Microsoft\Windows\Application Experience\Microsoft Compatibility Appraiser
# Task 16 --- Count: 14 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterUserDevice
# Task 17 --- Count: 12 --- TaskName: \Microsoft\Windows\InstallService\ScanForUpdates
# Task 18 --- Count: 12 --- TaskName: \Microsoft\Windows\Flighting\FeatureConfig\UsageDataFlushing
# Task 19 --- Count: 12 --- TaskName: \Microsoft\Windows\ExploitGuard\ExploitGuard MDM policy Refresh
# Task 20 --- Count: 12 --- TaskName: \Microsoft\Windows\WwanSvc\OobeDiscovery
# Task 21 --- Count: 10 --- TaskName: \Microsoft\Windows\WindowsUpdate\AUSessionConnect
# Task 22 --- Count: 10 --- TaskName: \Microsoft\Windows\Workplace Join\Automatic-Device-Join
# Task 23 --- Count: 10 --- TaskName: \Microsoft\Windows\Plug and Play\Device Install Reboot Required
# Task 24 --- Count: 10 --- TaskName: \Microsoft\Windows\Active Directory Rights Management Services Client\AD RMS Rights Policy Template Management (Automated)
# Task 25 --- Count: 10 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'All Windows Computers' - v. 16 (0c2997f8-e47a-4b61-8929-13374bdfb689)
# Task 26 --- Count: 10 --- TaskName: \Microsoft\Windows\SpacePort\SpaceAgentTask
# Task 27 --- Count: 10 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceAccountChange
# Task 28 --- Count: 10 --- TaskName: \GoogleUpdateTaskMachineCore
# Task 29 --- Count: 10 --- TaskName: \Microsoft\Windows\LanguageComponentsInstaller\Installation
# Task 30 --- Count: 10 --- TaskName: \Thycotic\Ensure UAC Override Setting (Windows) (906b2cfb-aa2c-45f6-a06f-49f9df13bc70)
# Task 31 --- Count: 10 --- TaskName: \Microsoft\Windows\WindowsColorSystem\Calibration Loader
# Task 32 --- Count: 10 --- TaskName: \Thycotic\Local User Inventory Policy (35f3fe35-4f02-4576-965f-bd0106816a8e)
# Task 33 --- Count: 10 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Windows Computers' - v. 16 (f4453ee5-47f0-4d6f-b36d-fb8bbc84e31b)
# Task 34 --- Count: 10 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDevicePolicyChange
# Task 35 --- Count: 10 --- TaskName: \Microsoft\Windows\SpacePort\SpaceManagerTask
# Task 36 --- Count: 10 --- TaskName: \Microsoft\Windows\AppID\EDP Policy Manager
# Task 37 --- Count: 10 --- TaskName: \Microsoft\Windows\Device Information\Device
# Task 38 --- Count: 10 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceSettingChange
# Task 39 --- Count: 10 --- TaskName: \Microsoft\Windows\RemoteAssistance\RemoteAssistanceTask
# Task 40 --- Count: 10 --- TaskName: \Microsoft\Windows\CertificateServicesClient\UserTask-Roam
# Task 41 --- Count: 10 --- TaskName: \Microsoft\Windows\SettingSync\NetworkStateChangeTask
# Task 42 --- Count: 10 --- TaskName: \Microsoft\Windows\WOF\WIM-Hash-Management
# Task 43 --- Count: 9 --- TaskName: \Microsoft\Windows\Diagnosis\RecommendedTroubleshootingScanner
# Task 44 --- Count: 8 --- TaskName: \Microsoft\Windows\WindowsUpdate\Scheduled Start With Network
# Task 45 --- Count: 8 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\USO_UxBroker
# Task 46 --- Count: 8 --- TaskName: \Microsoft\Windows\Data Integrity Scan\Data Integrity Check And Scan
# Task 47 --- Count: 8 --- TaskName: \Microsoft\Windows\DirectX\DirectXDatabaseUpdater
# Task 48 --- Count: 8 --- TaskName: \Microsoft\Windows\International\Synchronize Language Settings
# Task 49 --- Count: 8 --- TaskName: \Microsoft\Windows\PushToInstall\Registration
# Task 50 --- Count: 8 --- TaskName: \Microsoft\Windows\CertificateServicesClient\AikCertEnrollTask
# Task 51 --- Count: 8 --- TaskName: \Microsoft\Windows\GroupPolicy\{3E0A038B-D834-4930-9981-E89C9BFF83AA}
# Task 52 --- Count: 8 --- TaskName: \Microsoft\Windows\Flighting\OneSettings\RefreshCache
# Task 53 --- Count: 8 --- TaskName: \Microsoft\Windows\DirectX\DXGIAdapterCache
# Task 54 --- Count: 8 --- TaskName: \Microsoft\Windows\UNP\RunUpdateNotificationMgr
# Task 55 --- Count: 8 --- TaskName: \MicrosoftEdgeUpdateTaskMachineCore
# Task 56 --- Count: 8 --- TaskName: \Microsoft\Windows\Workplace Join\Recovery-Check
# Task 57 --- Count: 7 --- TaskName: \Thycotic\Cleanup and Configure Agent Inventory Transfers (Windows) (4b4c6a70-c88e-4062-8996-427443737130)
# Task 58 --- Count: 6 --- TaskName: \Microsoft\Windows\Data Integrity Scan\Data Integrity Scan
# Task 59 --- Count: 6 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1UK Domain' - v. 2 (d40c3249-252c-4451-bcd1-b58b0d2aef09)
# Task 60 --- Count: 6 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceScreenOnOff
# Task 61 --- Count: 6 --- TaskName: \Microsoft\Windows\PerfTrack\BackgroundConfigSurveyor
# Task 62 --- Count: 6 --- TaskName: \Adobe Acrobat Update Task
# Task 63 --- Count: 6 --- TaskName: \Microsoft\Windows\GroupPolicy\{A7719E0F-10DB-4640-AD8C-490CC6AD5202}
# Task 64 --- Count: 6 --- TaskName: \Microsoft\Windows\ApplicationData\appuriverifierinstall
# Task 65 --- Count: 5 --- TaskName: \Thycotic\Basic Inventory (Windows) (f0d0abc9-6858-45a8-9eee-0cff0590eac1)
# Task 66 --- Count: 5 --- TaskName: \Microsoft\Windows\Application Experience\ProgramDataUpdater
# Task 67 --- Count: 5 --- TaskName: \Microsoft\Windows\Shell\FamilySafetyMonitor
# Task 68 --- Count: 5 --- TaskName: \Microsoft\Windows\Customer Experience Improvement Program\Consolidator
# Task 69 --- Count: 5 --- TaskName: \Microsoft\Windows\Management\Provisioning\Cellular
# Task 70 --- Count: 5 --- TaskName: \Thycotic\Perform Resource Discovery (Windows) (70e817f1-b865-4061-a0fb-84331ad176c2)
# Task 71 --- Count: 5 --- TaskName: \Microsoft\Windows\WwanSvc\NotificationTask
# Task 72 --- Count: 5 --- TaskName: \Thycotic\User Logon Inventory Policy (c72e8356-81f6-47fd-bcb3-788e64fb0dff)
# Task 73 --- Count: 5 --- TaskName: \Microsoft\Windows\Plug and Play\Sysprep Generalize Drivers
# Task 74 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDevicePeriodic24
# Task 75 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceProtectionStateChanged
# Task 76 --- Count: 5 --- TaskName: \Microsoft\Windows\Maps\MapsToastTask
# Task 77 --- Count: 5 --- TaskName: \Microsoft\Windows\Active Directory Rights Management Services Client\AD RMS Rights Policy Template Management (Manual)
# Task 78 --- Count: 5 --- TaskName: \Microsoft\Windows\Autochk\Proxy
# Task 79 --- Count: 5 --- TaskName: \Microsoft\Windows\MemoryDiagnostic\RunFullMemoryDiagnostic
# Task 80 --- Count: 5 --- TaskName: \Microsoft\Windows\Windows Media Sharing\UpdateLibrary
# Task 81 --- Count: 5 --- TaskName: \Microsoft\Windows\Device Setup\Metadata Refresh
# Task 82 --- Count: 5 --- TaskName: \Microsoft\Windows\Feedback\Siuf\DmClient
# Task 83 --- Count: 5 --- TaskName: \Microsoft\Windows\Maps\MapsUpdateTask
# Task 84 --- Count: 5 --- TaskName: \Microsoft\Windows\DiskCleanup\SilentCleanup
# Task 85 --- Count: 5 --- TaskName: \Microsoft\Windows\Shell\CreateObjectTask
# Task 86 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceLocationRightsChange
# Task 87 --- Count: 5 --- TaskName: \Microsoft\Windows\EDP\StorageCardEncryption Task
# Task 88 --- Count: 5 --- TaskName: \Microsoft\Windows\MUI\LPRemove
# Task 89 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\LocateCommandUserSession
# Task 90 --- Count: 5 --- TaskName: \Microsoft\Windows\TextServicesFramework\MsCtfMonitor
# Task 91 --- Count: 5 --- TaskName: \Microsoft\Windows\.NET Framework\.NET Framework NGEN v4.0.30319
# Task 92 --- Count: 5 --- TaskName: \Microsoft\Windows\Feedback\Siuf\DmClientOnScenarioDownload
# Task 93 --- Count: 5 --- TaskName: \Microsoft\Windows\SoftwareProtectionPlatform\SvcRestartTaskNetwork
# Task 94 --- Count: 5 --- TaskName: \Microsoft\Windows\ApplicationData\DsSvcCleanup
# Task 95 --- Count: 5 --- TaskName: \Sophos Cloud Scheduled Scan
# Task 96 --- Count: 5 --- TaskName: \Microsoft\Windows\Sysmain\HybridDriveCacheRebalance
# Task 97 --- Count: 5 --- TaskName: \Microsoft\Windows\DiskDiagnostic\Microsoft-Windows-DiskDiagnosticResolver
# Task 98 --- Count: 5 --- TaskName: \Microsoft\Windows\Chkdsk\ProactiveScan
# Task 99 --- Count: 5 --- TaskName: \Microsoft\Windows\NlaSvc\WiFiTask
# Task 100 --- Count: 5 --- TaskName: \Microsoft\Windows\Customer Experience Improvement Program\UsbCeip
# Task 101 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\HandleWnsCommand
# Task 102 --- Count: 5 --- TaskName: \Microsoft\Windows\WOF\WIM-Hash-Validation
# Task 103 --- Count: 5 --- TaskName: \Microsoft\Windows\Offline Files\Logon Synchronization
# Task 104 --- Count: 5 --- TaskName: \Microsoft\Windows\DiskDiagnostic\Microsoft-Windows-DiskDiagnosticDataCollector
# Task 105 --- Count: 5 --- TaskName: \Microsoft\Windows\BitLocker\BitLocker MDM policy Refresh
# Task 106 --- Count: 5 --- TaskName: \Microsoft\Windows\Location\Notifications
# Task 107 --- Count: 5 --- TaskName: \Microsoft\Windows\PI\Secure-Boot-Update
# Task 108 --- Count: 5 --- TaskName: \Microsoft\Windows\DiskFootprint\Diagnostics
# Task 109 --- Count: 5 --- TaskName: \Microsoft\Windows\Maintenance\WinSAT
# Task 110 --- Count: 5 --- TaskName: \Microsoft\Windows\AppID\VerifiedPublisherCertStoreCheck
# Task 111 --- Count: 5 --- TaskName: \Microsoft\Windows\Multimedia\SystemSoundsService
# Task 112 --- Count: 5 --- TaskName: \Microsoft\Windows\SharedPC\Account Cleanup
# Task 113 --- Count: 5 --- TaskName: \Microsoft\Windows\Location\WindowsActionDialog
# Task 114 --- Count: 5 --- TaskName: \Microsoft\Windows\Storage Tiers Management\Storage Tiers Management Initialization
# Task 115 --- Count: 5 --- TaskName: \Microsoft\Windows\Management\Provisioning\Logon
# Task 116 --- Count: 5 --- TaskName: \Microsoft\Windows\Registry\RegIdleBackup
# Task 117 --- Count: 5 --- TaskName: \Microsoft\Windows\Application Experience\StartupAppTask
# Task 118 --- Count: 5 --- TaskName: \Microsoft\Windows\EDP\EDP Inaccessible Credentials Task
# Task 119 --- Count: 5 --- TaskName: \Microsoft\Windows\License Manager\TempSignedLicenseExchange
# Task 120 --- Count: 5 --- TaskName: \Microsoft\Windows\Time Zone\SynchronizeTimeZone
# Task 121 --- Count: 5 --- TaskName: \Microsoft\Windows\Offline Files\Background Synchronization
# Task 122 --- Count: 5 --- TaskName: \Microsoft\Windows\Shell\IndexerAutomaticMaintenance
# Task 123 --- Count: 5 --- TaskName: \Microsoft\Windows\.NET Framework\.NET Framework NGEN v4.0.30319 64
# Task 124 --- Count: 5 --- TaskName: \Microsoft\Windows\WCM\WiFiTask
# Task 125 --- Count: 5 --- TaskName: \Microsoft\Windows\DUSM\dusmtask
# Task 126 --- Count: 5 --- TaskName: \Microsoft\Windows\Sysmain\ResPriStaticDbSync
# Task 127 --- Count: 5 --- TaskName: \Microsoft\Windows\SoftwareProtectionPlatform\SvcRestartTask
# Task 128 --- Count: 5 --- TaskName: \Microsoft\Windows\SoftwareProtectionPlatform\SvcRestartTaskLogon
# Task 129 --- Count: 5 --- TaskName: \Microsoft\Windows\Clip\License Validation
# Task 130 --- Count: 5 --- TaskName: \Microsoft\Windows\Work Folders\Work Folders Logon Synchronization
# Task 131 --- Count: 5 --- TaskName: \Microsoft\Windows\ApplicationData\appuriverifierdaily
# Task 132 --- Count: 5 --- TaskName: \Microsoft\Windows\Time Synchronization\SynchronizeTime
# Task 133 --- Count: 5 --- TaskName: \Microsoft\Windows\Servicing\StartComponentCleanup
# Task 134 --- Count: 5 --- TaskName: \Thycotic\Update Applicable Policies (Windows) (6527b022-f19f-4326-87d9-c2d5c2f5f443)
# Task 135 --- Count: 5 --- TaskName: \Microsoft\Windows\SystemRestore\SR
# Task 136 --- Count: 5 --- TaskName: \GoogleUpdateTaskMachineUA
# Task 137 --- Count: 5 --- TaskName: \Microsoft\Windows\Shell\FamilySafetyRefreshTask
# Task 138 --- Count: 5 --- TaskName: \Microsoft\Windows\RecoveryEnvironment\VerifyWinRE
# Task 139 --- Count: 5 --- TaskName: \Microsoft\Windows\ApplicationData\CleanupTemporaryState
# Task 140 --- Count: 5 --- TaskName: \Microsoft\XblGameSave\XblGameSaveTask
# Task 141 --- Count: 5 --- TaskName: \Microsoft\Windows\CloudExperienceHost\CreateObjectTask
# Task 142 --- Count: 5 --- TaskName: \Microsoft\Windows\PI\Sqm-Tasks
# Task 143 --- Count: 5 --- TaskName: \Microsoft\Windows\Task Manager\Interactive
# Task 144 --- Count: 5 --- TaskName: \Microsoft\Windows\UPnP\UPnPHostConfig
# Task 145 --- Count: 5 --- TaskName: \Microsoft\Windows\Diagnosis\Scheduled
# Task 146 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\IntegrityCheck
# Task 147 --- Count: 5 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\HandleCommand
# Task 148 --- Count: 5 --- TaskName: \Microsoft\Windows\BrokerInfrastructure\BgTaskRegistrationMaintenanceTask
# Task 149 --- Count: 5 --- TaskName: \Microsoft\Windows\AppxDeploymentClient\Pre-staged app cleanup
# Task 150 --- Count: 5 --- TaskName: \Microsoft\Windows\Power Efficiency Diagnostics\AnalyzeSystem
# Task 151 --- Count: 5 --- TaskName: \Microsoft\Windows\EDP\EDP App Launch Task
# Task 152 --- Count: 5 --- TaskName: \Microsoft\Windows\FileHistory\File History (maintenance mode)
# Task 153 --- Count: 5 --- TaskName: \Microsoft\Windows\WDI\ResolutionHost
# Task 154 --- Count: 5 --- TaskName: \Microsoft\Windows\LanguageComponentsInstaller\Uninstallation
# Task 155 --- Count: 5 --- TaskName: \Thycotic\Scheduled Registration (Windows) (f1a711cf-479e-4808-9bab-689ab34a8a07)
# Task 156 --- Count: 5 --- TaskName: \Microsoft\Windows\Speech\SpeechModelDownloadTask
# Task 157 --- Count: 5 --- TaskName: \Microsoft\Windows\AppID\PolicyConverter
# Task 158 --- Count: 5 --- TaskName: \Microsoft\Windows\File Classification Infrastructure\Property Definition Sync
# Task 159 --- Count: 5 --- TaskName: \Microsoft\Windows\Bluetooth\UninstallDeviceTask
# Task 160 --- Count: 5 --- TaskName: \Microsoft\Windows\DiskFootprint\StorageSense
# Task 161 --- Count: 5 --- TaskName: \Thycotic\Send Azure AD Domain Info (a00b9b69-87e1-4ec1-8ee9-b49f8c741cc7)
# Task 162 --- Count: 5 --- TaskName: \Microsoft\Windows\CertificateServicesClient\CryptoPolicyTask
# Task 163 --- Count: 5 --- TaskName: \Microsoft\Windows\.NET Framework\.NET Framework NGEN v4.0.30319 Critical
# Task 164 --- Count: 5 --- TaskName: \Microsoft\Windows\Ras\MobilityManager
# Task 165 --- Count: 5 --- TaskName: \Microsoft\Windows\.NET Framework\.NET Framework NGEN v4.0.30319 64 Critical
# Task 166 --- Count: 5 --- TaskName: \Microsoft\Windows\Work Folders\Work Folders Maintenance Work
# Task 167 --- Count: 5 --- TaskName: \Thycotic\Update Agent Commands (Windows) (eb885e5a-53db-4142-a974-6022482d8078)
# Task 168 --- Count: 5 --- TaskName: \Microsoft\Windows\Defrag\ScheduledDefrag
# Task 169 --- Count: 5 --- TaskName: \Microsoft\Windows\Mobile Broadband Accounts\MNO Metadata Parser
# Task 170 --- Count: 5 --- TaskName: \Microsoft\Windows\Sysmain\HybridDriveCachePrepopulate
# Task 171 --- Count: 5 --- TaskName: \Microsoft\Windows\Storage Tiers Management\Storage Tiers Optimization
# Task 172 --- Count: 5 --- TaskName: \Microsoft\Windows\Data Integrity Scan\Data Integrity Scan for Crash Recovery
# Task 173 --- Count: 5 --- TaskName: \Microsoft\Windows\SettingSync\BackgroundUploadTask
# Task 174 --- Count: 5 --- TaskName: \Microsoft\Windows\EDP\EDP Auth Task
# Task 175 --- Count: 5 --- TaskName: \Thycotic\Update Provisioned Resource Client Items (Windows) (7ce60c6f-5ffd-40cd-a0cc-1f41d6956cc2)
# Task 176 --- Count: 5 --- TaskName: \Microsoft\Windows\Sysmain\WsSwapAssessmentTask
# Task 177 --- Count: 5 --- TaskName: \Microsoft\Windows\Windows Filtering Platform\BfeOnServiceStartTypeChange
# Task 178 --- Count: 5 --- TaskName: \Microsoft\Windows\Plug and Play\Device Install Group Policy
# Task 179 --- Count: 5 --- TaskName: \Microsoft\Windows\TPM\Tpm-HASCertRetr
# Task 180 --- Count: 5 --- TaskName: \Thycotic\Retry errored TMS Events (Windows) (26f84672-dcf4-48d5-b8e8-9943486ba68c)
# Task 181 --- Count: 5 --- TaskName: \Thycotic\Cleanup sent Privilege Manager Events (Windows) (e72aa7c6-6419-4b6d-a28a-e3d07f45e8db)
# Task 182 --- Count: 5 --- TaskName: \Microsoft\Windows\Time Synchronization\ForceSynchronizeTime
# Task 183 --- Count: 5 --- TaskName: \Microsoft\Windows\User Profile Service\HiveUploadTask
# Task 184 --- Count: 5 --- TaskName: \Microsoft\Windows\NetTrace\GatherNetworkInfo
# Task 185 --- Count: 5 --- TaskName: \Microsoft\Windows\Wininet\CacheTask
# Task 186 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Maintenance Install
# Task 187 --- Count: 4 --- TaskName: \FEMS_INSTALLER_0692b297_6b78_4bbc_8cd9_6a60937d5037
# Task 188 --- Count: 4 --- TaskName: \Microsoft\Windows\HelloFace\FODCleanupTask
# Task 189 --- Count: 4 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1auto - BMW Mini of El Paso' - v. 1 (912dd847-ea75-4bd8-ad29-f10d0b3b34f3)
# Task 190 --- Count: 4 --- TaskName: \Microsoft\Windows\Workplace Join\Device-Sync
# Task 191 --- Count: 4 --- TaskName: \MicrosoftEdgeUpdateTaskMachineUA
# Task 192 --- Count: 4 --- TaskName: \Microsoft\Windows\AppID\SmartScreenSpecific
# Task 193 --- Count: 4 --- TaskName: \Microsoft\Windows\Plug and Play\Plug and Play Cleanup
# Task 194 --- Count: 4 --- TaskName: \Microsoft\Windows\Input\PenSyncDataAvailable
# Task 195 --- Count: 4 --- TaskName: \Microsoft\Windows\WlanSvc\CDSSync
# Task 196 --- Count: 4 --- TaskName: \Microsoft\Windows\NetCfg\BindingWorkItemQueueHandler
# Task 197 --- Count: 4 --- TaskName: \Microsoft\Windows\RAC\RacTask
# Task 198 --- Count: 4 --- TaskName: \Microsoft\Windows\LanguageComponentsInstaller\ReconcileLanguageResources
# Task 199 --- Count: 4 --- TaskName: \Microsoft\Windows\EnterpriseMgmt\MDMMaintenenceTask
# Task 200 --- Count: 4 --- TaskName: \Microsoft\Windows\Chkdsk\SyspartRepair
# Task 201 --- Count: 4 --- TaskName: \Microsoft\Windows\Shell\UpdateUserPictureTask
# Task 202 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Schedule Maintenance Work
# Task 203 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Report policies
# Task 204 --- Count: 4 --- TaskName: \Microsoft\Windows\Application Experience\PcaPatchDbTask
# Task 205 --- Count: 4 --- TaskName: \Microsoft\Windows\InstallService\ScanForUpdatesAsUser
# Task 206 --- Count: 4 --- TaskName: \Microsoft\Windows\Input\TouchpadSyncDataAvailable
# Task 207 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\UpdateAssistant
# Task 208 --- Count: 4 --- TaskName: \Microsoft\Windows\Input\LocalUserSyncDataAvailable
# Task 209 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\UpdateModelTask
# Task 210 --- Count: 4 --- TaskName: \Microsoft\Windows\Input\MouseSyncDataAvailable
# Task 211 --- Count: 4 --- TaskName: \Microsoft\Windows\InstallService\WakeUpAndContinueUpdates
# Task 212 --- Count: 4 --- TaskName: \Microsoft\Windows\Shell\FamilySafetyMonitorToastTask
# Task 213 --- Count: 4 --- TaskName: \Microsoft\Windows\Device Information\Device User
# Task 214 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Reboot_AC
# Task 215 --- Count: 4 --- TaskName: \Microsoft\Windows\StateRepository\MaintenanceTasks
# Task 216 --- Count: 4 --- TaskName: \Microsoft\Windows\Printing\EduPrintProv
# Task 217 --- Count: 4 --- TaskName: \Microsoft\Windows\BitLocker\BitLocker Encrypt All Drives
# Task 218 --- Count: 4 --- TaskName: \Microsoft\Windows\WaaSMedic\PerformRemediation
# Task 219 --- Count: 4 --- TaskName: \Microsoft\Windows\PushToInstall\LoginCheck
# Task 220 --- Count: 4 --- TaskName: \Microsoft\Windows\Management\Provisioning\RunOnReboot
# Task 221 --- Count: 4 --- TaskName: \Microsoft\Windows\InstallService\WakeUpAndScanForUpdates
# Task 222 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Reboot
# Task 223 --- Count: 4 --- TaskName: \Microsoft\Windows\Management\Provisioning\Retry
# Task 224 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Schedule Wake To Work
# Task 225 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Reboot_Battery
# Task 226 --- Count: 4 --- TaskName: \Microsoft\Windows\Flighting\FeatureConfig\UsageDataReporting
# Task 227 --- Count: 4 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Schedule Work
# Task 228 --- Count: 3 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Backup Scan
# Task 229 --- Count: 3 --- TaskName: \Thycotic\Password Management Policy for user 'Guest' on computers in 'Group1UK Domain' (4605c43e-85be-4201-8542-42e8cb43e82a)
# Task 230 --- Count: 3 --- TaskName: \Microsoft\Windows\ErrorDetails\EnableErrorDetailsUpdate
# Task 231 --- Count: 3 --- TaskName: \Thycotic\Password Management Policy for user 'Administrator' on computers in 'Group1UK Domain' (4266dadf-3aaa-48c6-ae73-74da56782b76)
# Task 232 --- Count: 3 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDeviceConnectedToNetwork
# Task 233 --- Count: 3 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDevicePeriodic6
# Task 234 --- Count: 3 --- TaskName: \Microsoft\XblGameSave\XblGameSaveTaskLogon
# Task 235 --- Count: 3 --- TaskName: \Microsoft\Windows\DeviceDirectoryClient\RegisterDevicePeriodic1
# Task 236 --- Count: 3 --- TaskName: \Thycotic\Default File Inventory Policy (Windows) (8ab934c0-c9c8-47d5-b3f0-bb98f362fa0d)
# Task 237 --- Count: 3 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\USO_Broker_Display
# Task 238 --- Count: 3 --- TaskName: \Microsoft\Windows\Speech\HeadsetButtonPress
# Task 239 --- Count: 3 --- TaskName: \Microsoft\Windows\WindowsUpdate\sihpostreboot
# Task 240 --- Count: 3 --- TaskName: \Microsoft\Windows\ErrorDetails\ErrorDetailsUpdate
# Task 241 --- Count: 2 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1UK - Mercedes Benz of Norwich' - v. 1 (89069fba-0956-402c-a5f5-51673ea9c6e2)
# Task 242 --- Count: 2 --- TaskName: \Microsoft\Windows\SkyDrive\Idle Sync Maintenance Task
# Task 243 --- Count: 2 --- TaskName: \Thycotic\Password Management Policy for user 'Guest' on computers in 'Group1Auto Domain' (4502f891-d2f5-450e-a168-13711cd9a4a8)
# Task 244 --- Count: 2 --- TaskName: \Microsoft\Windows\Workplace Join\Automatic-Workplace-Join
# Task 245 --- Count: 2 --- TaskName: \Microsoft\Windows\WindowsUpdate\Automatic App Update
# Task 246 --- Count: 2 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-1993962763-1614895754-839522115-72687
# Task 247 --- Count: 2 --- TaskName: \Microsoft\Windows\SkyDrive\Routine Maintenance Task
# Task 248 --- Count: 2 --- TaskName: \Thycotic\Group Membership for Administrators in Group1Auto Domain - v. 5 (05252dcd-00b0-4bc4-885b-551b9043662a)
# Task 249 --- Count: 2 --- TaskName: \Microsoft\Office\OfficeTelemetryAgentFallBack2016
# Task 250 --- Count: 2 --- TaskName: \Microsoft\Windows\WindowsUpdate\AUFirmwareInstall
# Task 251 --- Count: 2 --- TaskName: \Microsoft\Windows\WindowsUpdate\AUScheduledInstall
# Task 252 --- Count: 2 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1UK - Stansted BMW' - v. 1 (7e77de94-21f2-45d7-bce3-4d17eb2b78be)
# Task 253 --- Count: 2 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1Auto Domain' - v. 4 (05252dcd-00b0-4bc4-885b-551b9043662a)
# Task 254 --- Count: 2 --- TaskName: \Thycotic\Password Management Policy for user 'Administrator' on computers in 'Group1Auto Domain' (f10e826a-1dbb-4805-b864-128d082b4297)
# Task 255 --- Count: 2 --- TaskName: \Microsoft\Windows\Customer Experience Improvement Program\BthSQM
# Task 256 --- Count: 2 --- TaskName: \Thycotic\Password Management Policy for user 'Administrator' on computers in 'US Domains' (56d30745-3630-4473-b8f0-67a661e980b2)
# Task 257 --- Count: 2 --- TaskName: \Microsoft\Windows\Shell\FamilySafetyUpload
# Task 258 --- Count: 2 --- TaskName: \Startup ISTA Launcher
# Task 259 --- Count: 2 --- TaskName: \Thycotic\Group Membership for 'Administrators' in 'Group1UK - Southend JLR' - v. 1 (20212151-66ea-4f51-9eca-d9a007dff261)
# Task 260 --- Count: 2 --- TaskName: \Microsoft\Windows\IME\SQM data sender
# Task 261 --- Count: 2 --- TaskName: \Stop ISTA Launcher
# Task 262 --- Count: 2 --- TaskName: \Microsoft\Office\Office 15 Subscription Heartbeat
# Task 263 --- Count: 2 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\MusUx_UpdateInterval
# Task 264 --- Count: 2 --- TaskName: \Microsoft\Windows\CUAssistant\CULauncher
# Task 265 --- Count: 2 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Universal Orchestrator Start
# Task 266 --- Count: 2 --- TaskName: \Microsoft\Office\OfficeTelemetryAgentLogOn2016
# Task 267 --- Count: 2 --- TaskName: \CCleaner Update
# Task 268 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-36590
# Task 269 --- Count: 1 --- TaskName: \G2MUpdateTask-S-1-5-21-670710141-1090052030-4155399046-12957
# Task 270 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Refresh Settings
# Task 271 --- Count: 1 --- TaskName: \Microsoft\Windows\WindowsUpdate\sihboot
# Task 272 --- Count: 1 --- TaskName: \RtHDVBg_PushButton
# Task 273 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Combined Scan Download Install
# Task 274 --- Count: 1 --- TaskName: \Optimize Start Menu Cache Files-S-1-5-21-2707071034-1007603500-2002257325-1002
# Task 275 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\SqlLiteRecoveryTask
# Task 276 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\mcupdate
# Task 277 --- Count: 1 --- TaskName: \User_Feed_Synchronization-{F803FDAA-3AF4-4714-839D-A4837ECF64FF}
# Task 278 --- Count: 1 --- TaskName: \Hewlett-Packard\HP Support Assistant\Update Check
# Task 279 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Policy Install
# Task 280 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\Resume On Boot
# Task 281 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\USO_UxBroker_Display
# Task 282 --- Count: 1 --- TaskName: \Microsoft\Windows\Tcpip\IpAddressConflict1
# Task 283 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\ReindexSearchRoot
# Task 284 --- Count: 1 --- TaskName: \Staging2
# Task 285 --- Count: 1 --- TaskName: \G2MUploadTask-S-1-5-21-670710141-1090052030-4155399046-12957
# Task 286 --- Count: 1 --- TaskName: \WPD\SqmUpload_S-1-5-21-1474103988-3333907210-3290273679-1002
# Task 287 --- Count: 1 --- TaskName: \Microsoft\Windows\Tcpip\IpAddressConflict2
# Task 288 --- Count: 1 --- TaskName: \Intel PTT EK Recertification
# Task 289 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-6729
# Task 290 --- Count: 1 --- TaskName: \Microsoft\Windows\Shell\WindowsParentalControls
# Task 291 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\OCURDiscovery
# Task 292 --- Count: 1 --- TaskName: \Microsoft\Windows\SideShow\SessionAgent
# Task 293 --- Count: 1 --- TaskName: \User_Feed_Synchronization-{39282366-F948-4E0D-9529-503E37805A87}
# Task 294 --- Count: 1 --- TaskName: \User_Feed_Synchronization-{C42CB261-08B2-4559-93CD-5D235DF8C879}
# Task 295 --- Count: 1 --- TaskName: \Microsoft\Windows\SideShow\AutoWake
# Task 296 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PeriodicScanRetry
# Task 297 --- Count: 1 --- TaskName: \Agent Activation Runtime\S-1-5-21-670710141-1090052030-4155399046-36590
# Task 298 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\DispatchRecoveryTasks
# Task 299 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\RecordingRestart
# Task 300 --- Count: 1 --- TaskName: \Microsoft\Windows\Customer Experience Improvement Program\Uploader
# Task 301 --- Count: 1 --- TaskName: \User_Feed_Synchronization-{2590C1E1-B9D9-4355-9003-897AEB5B349E}
# Task 302 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PBDADiscoveryW1
# Task 303 --- Count: 1 --- TaskName: \Microsoft\Windows Defender\MP Scheduled Scan
# Task 304 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\ActivateWindowsSearch
# Task 305 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-1474103988-3333907210-3290273679-1002
# Task 306 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\RegisterSearch
# Task 307 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PBDADiscovery
# Task 308 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\ConfigureInternetTimeService
# Task 309 --- Count: 1 --- TaskName: \Hewlett-Packard\HP Support Assistant\HP Support Assistant Quick Start
# Task 310 --- Count: 1 --- TaskName: \npcapwatchdog
# Task 311 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\mcupdate_scheduled
# Task 312 --- Count: 1 --- TaskName: \Microsoft\Windows\Customer Experience Improvement Program\KernelCeipTask
# Task 313 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-37902
# Task 314 --- Count: 1 --- TaskName: \Microsoft\Windows\SettingSync\BackupTask
# Task 315 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-33624
# Task 316 --- Count: 1 --- TaskName: \Microsoft\Windows\SideShow\SystemDataProviders
# Task 317 --- Count: 1 --- TaskName: \CreateExplorerShellUnelevatedTask
# Task 318 --- Count: 1 --- TaskName: \Optimize Start Menu Cache Files-S-1-5-21-1474103988-3333907210-3290273679-1002
# Task 319 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\ehDRMInit
# Task 320 --- Count: 1 --- TaskName: \Microsoft\Windows\Shell\WindowsParentalControlsMigration
# Task 321 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PvrRecoveryTask
# Task 322 --- Count: 1 --- TaskName: \Hewlett-Packard\HP Support Assistant\PC Health Analysis
# Task 323 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PBDADiscoveryW2
# Task 324 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\OCURActivate
# Task 325 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-31705
# Task 326 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-1060006010-4222403633-3924226086-500
# Task 327 --- Count: 1 --- TaskName: \Microsoft\Windows\MobilePC\HotStart
# Task 328 --- Count: 1 --- TaskName: \Microsoft\Windows\rempl\shell
# Task 329 --- Count: 1 --- TaskName: \Microsoft\Windows\UpdateOrchestrator\USO_UxBroker_ReadyToReboot
# Task 330 --- Count: 1 --- TaskName: \User_Feed_Synchronization-{9D633DE1-2709-4792-A8EF-343C0B4E547D}
# Task 331 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\PvrScheduleTask
# Task 332 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\InstallPlayReady
# Task 333 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\MediaCenterRecoveryTask
# Task 334 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\ObjectStoreRecoveryTask
# Task 335 --- Count: 1 --- TaskName: \Microsoft\Windows\SideShow\GadgetManager
# Task 336 --- Count: 1 --- TaskName: \Microsoft\Windows\Conexant\MicTray
# Task 337 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-670710141-1090052030-4155399046-12957
# Task 338 --- Count: 1 --- TaskName: \Agent Activation Runtime\S-1-5-21-1474103988-3333907210-3290273679-1002
# Task 339 --- Count: 1 --- TaskName: \Microsoft\Windows\Media Center\UpdateRecordPath
# Task 340 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task-S-1-5-21-2707071034-1007603500-2002257325-1002
# Task 341 --- Count: 1 --- TaskName: \Microsoft\Windows\WindowsUpdate\sih
# Task 342 --- Count: 1 --- TaskName: \OneDrive Standalone Update Task v2

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 5:__ _Filtering Out Pre-Specified Tasks_ ###
# __Note:__
# - No printing / output in this section
# - _Vanilla_dataset_ contains all entries that have been checked against a list of tasks deemed "safe"
# - _NeedsThreatHunting_Dataset_ contains all entries that still need to be checked for potentially malicious tasks
#
# - All tasks that match/contain the "keyword(s)" in VanillaTasks will be added to vanilla_dataset
# - All tasks that DO NOT match/contain the "keyword(s)" in VanillaTasks will be added to NeedsThreatHunting_dataset
#
# - Stored in Python as a _list_

# %%
## PARSING THROUGH COMBINED LIST OF ALL DATAPOINTS FOR SEARCH TERMS ##
vanilla_dataset = []  
NeedsThreatHunting_dataset = [] 

VanillaTasks1 = create_list_from_file(file_path)
VanillaTasks = []     
for eachtask in VanillaTasks1:
    VanillaTasks.append(eachtask[0])
    
for row in fulldataset:
    name = row[1]
    boolean = VanillaFilter(name)
    if boolean == True:
        vanilla_dataset.append(row)
    elif boolean == False:
        NeedsThreatHunting_dataset.append(row)

# %% [markdown]
# =========================================================================================================
#
# ### __SECTION 6:__ _Output / Verification_ ###
# __Note:__
# - Prints:
#     - 'Num. of Tasks Deemed Safe'
#         - _What's filtered out_
#     - 'Num. of Tasks Left To Check'
#         - _TaskNames whose names or keyword could not be found in the VanillaFilter CSV_
#     - 'Total Number of Tasks Filtered'
#         - _Self explanatory_
#     - 'Expected Number of Tasks Filtered'
#         - _Self explanatory_
# - If the Total and Expected Number of Tasks Filtered differ in any way, something broke during the sorting process
# - Stored in Python as an _Integer_

# %%
## OUTPUT / VERIFCATION ##        
print('Tasks Deemed Safe =', len(vanilla_dataset), '(AKA Vanilla Dataset)')        
print('Tasks Left to Check =', len(NeedsThreatHunting_dataset), '(AKA Threat Hunting Dataset)')
print('Total =', (len(vanilla_dataset) + len(NeedsThreatHunting_dataset)))
print('\n')
print('Expected Total =', len(fulldataset))
# Out:
# Tasks Deemed Safe = 16 (AKA Vanilla Dataset)
# Tasks Left to Check = 2205 (AKA Threat Hunting Dataset)
# Total = 2221
#
#
# Expected Total = 2221

# %% [markdown]
# =========================================================================================================
#
# # Additional Notes on Setup:
# - In Section 2, you are required to input __two__ different paths, one for a directory and one for a file
#     - The _directory path_ should lead to a folder that contains all CSV files with data to be inspected
#     - The _file path_ should lead to a singlular CSV file that contains all names or keywords related to Scheduled Tasks data you would like to see filtered out of the dataset, hence the name "VanillaTasks"
#
# - Setting up the file containing "Vanilla Tasks":
#     - Create a new excel document
#     - In cell __A1__, add an arbitrary column header like 'Vanilla Tasks to Remove'
#         - This will not be used to filter, but is required
#     - In cell __A2, A3, A4, etc__, type _names_ or _keywords_ of tasks you'd like filtered out
#     - Click "File", "Save as"
#         - __File Name:__ _arbitrary_, __ex:__ VanillaTasks.csv
#         - __File type:__ _'CSV (Comma delimited) (*.csv)'_
#
# - Vanilla Tasks _keyword_ / _name_ Example:
#     - If TaskName is _'\Adobe Flash Player Update'_, then the "keyword(s)" added to 'Vanilla Tasks' CSV could be:
#         - _'Adobe Flash Player Update'_   <--- __Most__ exact, less likely to filter other tasks by accident
#         - _'Adobe'_                       <--- __Least__ exact, more likely to filter other tasks by accident
#
# - Setting up the directory containg the 12,000+ CSVs:
#     - Two, very simple steps:
#         - Throw every CSV file you want to work with into a single folder
#         - Copy and paste the file path of this folder into its designated spot within this script (Refer to Section 2)
